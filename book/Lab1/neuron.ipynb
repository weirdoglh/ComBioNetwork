# %% [markdown]
# # Neuron, Input, and Synapse
#
# ## How to use this notebook
#
# > You do not need to understand the code. Your job is to **run the simulations, make predictions, and answer the questions.**
#
# This notebook is a lab workbook — **write your answers directly into the answer boxes as you go.** At the end of the lab you will export it as a PDF to submit for correction.
#
# Each section follows the same structure:
# 1. **Predict** — write down what you expect *before* running the simulation
# 2. **Explore** — use the interactive widget to test your prediction
# 3. **Explain** — answer the questions based on what you observed
#
# ---
#
# ## Neuron model
#
# Real neurons receive inputs, integrate them, and fire action potentials in characteristic patterns. Different neuron types fire in very different ways — some fire steadily, some burst, some slow down over time.
#
# In this section we use a model called the **Adaptive Leaky Integrate-and-Fire (AdLIF) neuron**. It captures two key biological features:
#
# - **Membrane integration** — the neuron accumulates input until it reaches a threshold and fires
# - **Adaptation** — after firing, the neuron becomes harder to excite again, mimicking real ionic currents

# %%
#@title Run the following to initialize lab environment.

# !pip install ipympl ipywidgets stg-net -q

import matplotlib.pyplot as plt         # import matplotlib
from matplotlib.widgets import Slider
import numpy as np                      # import numpy
import ipywidgets as widgets            # interactive display

# Colab setting for widget
try:
    from google.colab import output
    output.enable_custom_widget_manager()
except ImportError:
    pass

# modeling library
from stg_net.neuron import LIF
from stg_net.input import Poisson_generator, Gaussian_generator, Current_injector
from stg_net.conn import Simulator
from stg_net.helper import plot_volt_trace

# Educational Setup: defining parameters with biological context
# tau_m: Membrane time constant (how fast the voltage changes)
# a: Sub-threshold adaptation (coupling between V and w)
# tau_w: Adaptation time constant (recovery time)
# b: Spike-triggered adaptation (increase in w after a spike)
# V_reset: Voltage after a spike

fig_w, fig_h = 8, 6
my_fontsize = 18
my_params = {'axes.labelsize': my_fontsize,
          'axes.titlesize': my_fontsize,
          'figure.figsize': (fig_w, fig_h),
          'font.size': my_fontsize,
          'legend.fontsize': my_fontsize-4,
          'lines.markersize': 8.,
          'lines.linewidth': 2.,
          'xtick.labelsize': my_fontsize-2,
          'ytick.labelsize': my_fontsize-2}
plt.rcParams.update(my_params)
my_layout = widgets.Layout()

# Auto Reloading - disabled due to Python 3.12 compatibility
# %load_ext autoreload
# %autoreload 2

# Set plotting backend to inline for Colab compatibility
# %matplotlib inline

# %% [markdown]
# ## Part 1: What controls how a neuron fires?
#
#
# <center>
#     <img src="https://github.com/weirdoglh/ComBioNetwork/blob/main/book/Lab1/von-neumanns-elephant.png?raw=true" alt="Pyloric colour" width="300">
# </center>
#
#
#
# > John von Neumann famously said: *"with four parameters I can fit an elephant, and with six I can make it wiggle its trunk."* We have six so let's see what they can do.
#
# ### The parameters — what do they mean biologically?
#
# Before you touch the sliders - what are our 6 parameters?
#
#
#
# ---

# %% [markdown]
# | Parameter | What it controls | Biological meaning |
# |-----------|-----------------|-------------------------------------------|
# | **Icur** | Input current | `__________` |
# | **τm** | Membrane time constant | `__________` |
# | **V_reset** | Reset voltage | `__________` |
# | **a** | Subthreshold adaptation | `__________` |
# | **b** | Spike-triggered adaptation | `__________` |
# | **τw** | Adaptation time constant | `__________` |

# %% [markdown]
# <details>
# <summary><strong>Click to reveal the biological meaning of each parameter</strong></summary>
#
# <br>
#
# | Parameter | What it controls | Biological meaning |
# |-----------|-----------------|-------------------|
# | **Icur** | Input current | How much excitatory drive the neuron receives — like synaptic input from other neurons |
# | **τm** | Membrane time constant | How quickly the membrane voltage responds to input |
# | **V_reset** | Reset voltage | How hyperpolarised the neuron becomes after firing - Afterhyperpolarization amplitude |
# | **a** | Subthreshold adaptation | How adaptation builds up between spikes |
# | **b** | Spike-triggered adaptation | How adaptation jumps after each spike |
# | **τw** | Adaptation time constant | How slowly adaptation recovers |
# </details>

# %% [markdown]
# ### Step 1: Predict (before touching the widget)
#
# ** Write your answers below before running anything.**
#
# *If you increase Icur (input current), what do you predict will happen to the neuron's firing?*
#
# **My prediction:**
# ```
# [Write here]
# ```
#
# *Do you think the neuron will fire differently with a short τm vs a long τm? Why?*
#
# **My prediction:**
# ```
# [Write here]
# ```
#
# ---
#
# ### Step 2: Explore — Phase 1 (Icur only)
#
# Run the simulation below. **For now, only change Icur** and leave all other sliders at their default values.
#
#
# Start with `Icur = 5` and slowly increase it to `70`.

# %%
#@title Run the following to start the simulation of single neuron { vertical-output: true }
T, dt = 5e2, 0.1    # simulation period(ms), step size(ms)
wt, dl = 1., 5.
rt = 65.

# simualtor
h = Simulator(dt=dt)

# neurons
nrn = LIF(sim=h)
nrn.g_L = 2.
nrn.E_L = -70.
nrn.V_th = -40.

tonic_neuron = {'tau_m':20., 'a':0., 'tau_w':30., 'b':3., 'V_reset':-55.}
adapting_neuron = {'tau_m':20., 'a':0., 'tau_w':100., 'b':0.5, 'V_reset':-55.}
initburst_neuron = {'tau_m':10., 'a':0., 'tau_w':100., 'b':1., 'V_reset':-50.}
bursting_neuron = {'tau_m':5., 'a':0., 'tau_w':100., 'b':1., 'V_reset':-46.}
irregular_neuron = {'tau_m':10., 'a':-0.01, 'tau_w':50., 'b':1.2, 'V_reset':-46.}
transient_neuron = {'tau_m':5., 'a':0.05, 'tau_w':100., 'b':0.7, 'V_reset':-60.}
delayed_neuron = {'tau_m':50, 'a':-0.1, 'tau_w':100., 'b':1., 'V_reset':-60.}

neuron_params = {'tonic_neuron': tonic_neuron, 'adapting_neuron': adapting_neuron,
                 'initburst_neuron': initburst_neuron, 'bursting_neuron': bursting_neuron,
                 'irregular_neuron': irregular_neuron, 'transient_neuron': transient_neuron,
                 'delayed_neuron': delayed_neuron, 'my_neuron': tonic_neuron}
# tonic
nrn.tau_m = 20.
nrn.tau_w = 30.
nrn.b = 3
nrn.V_reset = -55.

# current injection
cur_in = Current_injector(sim=h, rate=rt, start=int(T/dt*0.1), end=int(T/dt*0.9))
nrn.connect(cur_in, {'ctype':'Static', 'weight': wt, 'delay':dl})

# updating parameters
def update(Icur=65., tau_m=20., V_reset=-55., a=0., tau_w=30., b=0., neuron_type='my_neuron'):
    if neuron_type == 'my_neuron':
      neuron_params['my_neuron'] = {'tau_m':tau_m, 'a':a, 'tau_w':tau_w, 'b':b, 'V_reset':V_reset}
    nrn.update(neuron_params[neuron_type])

    # constant current injection
    cur_in.rate = Icur

    # simulate
    h.run(T)

    # visualize
    plt.figure(figsize=(8, 6))
    plt.title('firing patterns')
    plt_par = {'dt':dt, 'range_t':np.arange(0., T, dt), 'V_th':nrn.V_th}
    plot_volt_trace(plt_par, nrn.v, np.array(nrn.spikes['times']))
    plt.xlim([0, 350])
    plt.ylim([-80, -20])
    plt.tight_layout()
    plt.show()

widgets.interact(update, neuron_type=neuron_params.keys(), tau_m=(5.0, 20.0, 1.0), a=(-0.1, 0.1, 0.01), tau_w=(30., 120., 10.), b=(0., 3., 0.1), V_reset=(-60., -40., 2.), Icur=(5., 70., 5.));
# Out:
# interactive(children=(FloatSlider(value=65.0, description='Icur', max=70.0, min=5.0, step=5.0), FloatSlider(va…

# %% [markdown]
# ### Step 3: Explain — Phase 1
#
# *What happened to the firing rate as you increased Icur?*
#
# **My answer:**
# ```
# [Write here]
# ```
#
# *Was there a minimum value of Icur needed before the neuron fired at all? What was it approximately?*
#
# **My answer:**
# ```
# [Write here]
# ```
#
# ---
#
# ### Explore — Phase 2 (τm and V_reset)
#
# Now keep Icur at a fixed value (try **Icur = 50**) and explore **τm** and **V_reset** only.
#
# *What happens to firing when you decrease τm from 20 to 5?*
#
# **My answer:**
# ```
# [Write here]
# ```
#
# *What happens when you make V_reset more negative (e.g. -60 vs -46)?*
#
# **My answer:**
# ```
# [Write here]
# ```
#
# ---
#
# ### Explore — Phase 3 (Adaptation: a, b, τw)
#
# Keep Icur = 50, reset τm and V_reset to defaults, and now explore **a**, **b**, and **τw**.
#
# *Increase b gradually from 0 to 3. What changes about the firing pattern?*
#
# **My answer:**
# ```
# [Write here]
# ```
#
# *Now increase τw. How does this interact with b?*
#
# **My answer:**
# ```
# [Write here]
# ```
# ___
#
# ### Preset neuron types — matching model to biology
#
# The dropdown menu contains preset neuron types based on real biological neurons.
# Select each one and observe the firing pattern, then match them to the descriptions below.
#
# | Preset name | What it looks like | Real biological example (fill in first!) |
# |-------------|-------------------|-------------------------------------------|
# | **tonic_neuron** | Fires steadily throughout | `__________` |
# | **adapting_neuron** | Starts fast, slows down | `__________` |
# | **initburst_neuron** | Burst at start, then regular | `__________` |
# | **bursting_neuron** | Repeated rhythmic bursts | `__________` |
# | **irregular_neuron** | Unpredictable spacing | `__________` |
# | **transient_neuron** | Only fires at the very start | `__________` |
# | **delayed_neuron** | Long pause before first spike | `__________` |

# %% [markdown]
# <details>
# <summary><strong>Click to reveal real neuron examples + links to papers</strong></summary>
#
# <br>
#
# | Preset name | What it looks like | Real biological example + reference |
# |-------------|-------------------|-------------------------------------|
# | **tonic_neuron** | Fires steadily throughout | Striatal Cholinergic Interneurons — Tonically active neurons (TANs) that maintain steady firing without input. Ref: Bennett & Wilson (1999). https://doi.org/10.1523/JNEUROSCI.19-13-05586.1999|
# | **adapting_neuron** | Starts fast, slows down | Visual Cortex Layer 5 Pyramids — Exhibit spike-frequency adaptation via M-current activation. Ref: McCormick et al. (1985). https://doi.org/10.1113/jphysiol.1985.sp015584 |
# | **initburst_neuron** | Burst at start, then regular | Thalamic Relay Neurons — Transition from T-type Ca²⁺ bursts to tonic firing based on polarization. Ref: Sherman (2001). https://doi.org/10.1152/jn.2001.86.1.1 |
# | **bursting_neuron** | Repeated rhythmic bursts | Pre-Bötzinger Complex Neurons — Endogenous rhythmic bursting that drives respiratory cycles. Ref: Smith et al. (1991). https://doi.org/10.1126/science.1835750 |
# | **irregular_neuron** | Unpredictable spacing | Cerebellar Purkinje Cells **§** — Show highly irregular simple-spike intervals in vivo due to synaptic noise. Ref: Hausser & Clark (1997). https://doi.org/10.1016/S0896-6273(00)80396-7 |
# | **transient_neuron** | Only fires at the very start | Cochlear Nucleus Bushy Cells — Fire a single precise spike at the onset of stimuli for sound localization. Ref: Rothman & Manis (2003). https://doi.org/10.1152/jn.00127.2002 |
# | **delayed_neuron** | Long pause before first spike | Pyramidal neurons in the superficial layers of rat retrosplenial cortex exhibit a late-spiking firing property. Ref: Kurotani et al. (2012). https://doi.org/10.1007/s00429-012-0398-1|
#
# **§ A Note on the "Irregular" Neuron:** *While most neurons can be made to fire irregularly by bombarding them with random synaptic inputs (noise), the Cerebellar Purkinje cell is a fantastic real-world example because its high-frequency baseline combined with inhibitory inputs creates a very distinctive "stochastic" (unpredictable) pattern that is vital for motor timing.*
#
# </details>

# %% [markdown]
# *Choose two preset types that look most different from each other. Which parameters are most responsible for the difference?*
#
# **My answer:**
# ```
# [Write here]
# ```
#
# *Can you think of a situation in real brain function where a bursting pattern would be useful vs a tonic pattern?*
#
# **My answer:**
# ```
# [Write here]
# ```
#
# ---
#
# ### Checkpoint 1
#
# Before moving on, make sure you can answer these:
#
# - Increasing Icur mainly affects: ______
# - τm mainly controls: ______
# - The adaptation parameters (a, b, τw) mainly control: ______
# - One real neuron type that shows adaptation is: ______
#
# ___

# %% [markdown]
# ### Equations
# Neuron dynamaics: let's open the blackbox of the neuron
#
# $$\tau_m \frac{dV}{dt} = -(V-V_{rest}) + \Delta_T exp(\frac{V-V_{rh}}{\Delta_T}) - Rw + RI(t)$$
# $$\tau_w \frac{dw}{dt} = a(V-V_{rest}) -w + b
# \tau_w \sum_{t^{(f)}} \delta(t-t^{(f)})$$
#
# It's described by two variables $V$ and $w$ which denote the membrane potential and adaptation current. The parameters $a, b, \tau_w$ controls the behavior of adaptation where $a$ controls sub-threshold adaptation and $b, \tau_w$ controls spike adaptation. For detailed explanation of this mode, refer to the book we mentioned at the beginning.
#
# ___

# %% [markdown]
# ## Part 2: How do neurons influence each other?
#
# Neurons communicate through **synapses**. In the simulation below, Neuron 1 (blue) receives constant input and drives Neuron 2 (red) through a synapse.
#
# There are four connection types available:
#
# | Type | What it models | Biological meaning |
# |------|----------------|-------------------|
# | **Static** | <details><summary>Click to show</summary>Fixed synaptic weight</details> | <details><summary>Click to show</summary>A stable, unchanging connection</details> |
# | **Faci** (Facilitation) | <details><summary>Click to show</summary>Weight increases with each spike</details> | <details><summary>Click to show</summary>Synapses that strengthen with repeated use — found at some motor synapses</details> |
# | **Depr** (Depression) | <details><summary>Click to show</summary>Weight decreases with each spike</details> | <details><summary>Click to show</summary>Synapses that weaken with repeated use — very common in cortex, thought to act as high‑pass filters</details> |
# | **Gap** | <details><summary>Click to show</summary>Direct electrical coupling</details> | <details><summary>Click to show</summary>Gap junctions — neurons share voltage directly, no chemical neurotransmitter signaling</details> |
#
#
#
# ### Predict
#
# *Which synapse type do you think will produce the most synchronised firing between the two neurons?*
#
# **My prediction:**
# ```
# [Write here]
# ```
#
# *Do you think chemical synapses (Static, Faci, Depr) or gap junctions will transmit signals faster? Why?*
#
# **My prediction:**
# ```
# [Write here]
# ```

# %%
#@title Run the following to start synapse simulation { vertical-output: true }
rt = 100.
N = 2                  # number of neurons

# input types
Itypes = ['Icur', 'Gaussian', 'Poisson']

# connection types
Ctypes = ['Static', 'Faci', 'Depr', 'Gap']

# updating parameters
def update_syn(c_ie='Static'):
    # simualtor
    h = Simulator(dt=dt)

    # network of neurons
    nrns = [LIF(sim=h) for _ in range(N)]

    nrns[0].update(tonic_neuron)
    nrns[1].update(tonic_neuron)

    # background noise
    noise = Current_injector(sim=h, rate=rt, start=int(T/dt*0.1), end=int(T/dt*0.9))
    nrns[0].connect(noise, {'ctype':'Static', 'weight':wt, 'delay':dl})

    # recurrent connections
    tps = [['Static']*N]*N
    J_ei = 0.
    tps[1][0] = c_ie
    if c_ie == 'Gap':
        J_ie = J_ei = 10
        tps[0][1] = tps[1][0] = c_ie
    elif c_ie == 'Static':
        J_ie = 1.0
    elif c_ie == 'Faci':
        J_ie = 1.0
    elif c_ie == 'Depr':
        J_ie = 1.0
    con = np.array([[0., J_ei],
                    [J_ie, 0.]])
    dly = np.random.uniform(2., 5., (N,N))
    synspecs = [[{} for _ in range(N)] for _ in range(N)]
    for i in range(N):
        for j in range(N):
            synspecs[i][j] = {'ctype':tps[i][j], 'weight':con[i,j], 'delay':dly[i,j]}
    h.connect(nrns, nrns, synspecs)

    # simulation
    h.run(T)

    # visualize
    plt.figure(figsize=(5*N, 8))
    cs = ['b', 'r']
    plt.subplot(2,N,1)
    plt.title('raster')
    for nrn, c, l in zip(nrns, cs, range(N)):
        plt.eventplot(nrn.spikes['times'], lineoffsets=2*l, colors=c, label='%dHz'%(len(nrn.spikes['times'])/T*1e3))
    plt.xlabel('Time(ms)')
    plt.yticks([0, 2], ['N_src', 'N_tar'])
    plt.xlim([0., T])
    plt.legend()

    # voltage traces
    plt.subplot(2,N,N+1)
    for id, c in zip(range(N), cs):
        if id == 0:
            plt.title('voltage trace')
        plt_par = {'dt':dt, 'range_t':np.arange(0., T, dt), 'V_th':nrns[id].V_th}
        plot_volt_trace(plt_par, nrns[id].v, np.array(nrns[id].spikes['times']), c=c)
        plt.xlim([0., T])

    plt.tight_layout()
    plt.show()

widgets.interact(update_syn, c_ie=Ctypes);
# Out:
# interactive(children=(Dropdown(description='c_ie', options=('Static', 'Faci', 'Depr', 'Gap'), value='Static'),…

# %% [markdown]
# ### Explain — Synapse types
#
# *Compare Static and Gap junction. What do you notice about the timing of spikes in Neuron 2 relative to Neuron 1?*
#
# **My answer:**
# ```
# [Write here]
# ```
#
# *With Facilitation (Faci): how does the firing of Neuron 2 change over time as Neuron 1 keeps firing?*
#
# **My answer:**
# ```
# [Write here]
# ```
#
# *With Depression (Depr): what happens to the response of Neuron 2 over time?*
#
# **My answer:**
# ```
# [Write here]
# ```
#
# *Which type of short‑term synaptic plasticity (depression or facilitation) would help a neuron respond more strongly to the onset of a stimulus? Why?*
#
# **My answer:**
# ```
# [Write here]
# ```
#
# ### Checkpoint 2
#
# - The synapse type that transmits with the shortest delay is: ______
# - Synaptic depression could be useful in biology because: ______
# - One difference between chemical synapses and gap junctions is: ______

# %% [markdown]
# ## Part 3: What kinds of input do neurons receive?
#
# In the real brain, neurons never receive perfectly smooth, constant input. The simulation below shows three types of input a neuron might receive:
#
# | Input type | What it models | Biological context |
# |-----------|----------------|-------------------|
# | **Icur** | <details><summary>Click to show</summary>Constant current injection</details> | <details><summary>Click to show</summary>A lab experiment — a researcher injects steady current through an electrode</details> |
# | **Gaussian** | <details><summary>Click to show</summary>Noisy fluctuating current</details> | <details><summary>Click to show</summary>The background "hum" of thousands of weak synaptic inputs arriving randomly</details> |
# | **Poisson** | <details><summary>Click to show</summary>Discrete spike train</details> | <details><summary>Click to show</summary>Input from a single presynaptic neuron firing at random intervals</details> |
#
#
# ### Predict
#
# *Which input type do you think most closely resembles what a neuron in the brain actually experiences during normal activity? Why?*
#
# **My prediction:**
# ```
# [Write here]
# ```

# %%
#@title Run the following to start input simulation { vertical-output: true }

def update_inp(Itype='Icur'):
    h = Simulator(dt=dt)

    # background noise
    if Itype == 'Icur':
        noise = Current_injector(sim=h, rate=50.0,
                                 start=int(T/dt*0.1),
                                 end=int(T/dt*0.9))
    elif Itype == 'Gaussian':
        noise = Gaussian_generator(sim=h, mean=0., std=50.0)
    elif Itype == 'Poisson':
        noise = Poisson_generator(sim=h, rate=50.0)
    else:
        print('Invalid input')
        return

    h.run(T)

    # --- Visualization ---
    plt.figure(figsize=(10, 4))

    if Itype == 'Icur':
        plt.plot(noise.Is, color='tab:blue')
        plt.title("Constant Current Injection (Icur)")
        plt.ylabel("Current (nA)")

    elif Itype == 'Gaussian':
        plt.step(range(len(noise.Is)), noise.Is, where='mid', color='tab:green')
        plt.title("Gaussian Noise Input")
        plt.ylabel("Current (nA)")

    elif Itype == 'Poisson':
        spike_times = np.where(noise.spike_train > 0)[0]

        # Raster-style vertical ticks
        for t in spike_times:
            plt.vlines(t, 0, 1, color='tab:red', linewidth=1.2)

        plt.title("Poisson Spike Train (Raster Plot)")
        plt.ylabel("Spike")
        plt.ylim(0, 1.2)

    plt.xlabel("Time (ms)")
    plt.tight_layout()
    plt.show()

widgets.interact(update_inp, Itype=['Icur', 'Gaussian', 'Poisson']);
# Out:
# interactive(children=(Dropdown(description='Itype', options=('Icur', 'Gaussian', 'Poisson'), value='Icur'), Ou…

# %%
#@title Run the following to start input simulation { vertical-output: true }

import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import interact, Layout

# --- Adapting IF model (Euler integration) ---
def aif_response(I_t, dt=0.1, T=1000.0,
                 V_rest=-65.0, V_th=-50.0, V_reset=-65.0,
                 R=100.0, tau_m=20.0,
                 tau_w=200.0, b=0.5):
    steps = int(T/dt)
    V = np.zeros(steps)
    w = np.zeros(steps)
    spikes = np.zeros(steps, int)
    V[0] = V_rest
    for i in range(1, steps):
        dV = ((V_rest - V[i-1]) + R * (I_t[i-1] - w[i-1])) * (dt / tau_m)
        V[i] = V[i-1] + dV
        dw = (-w[i-1]) * (dt / tau_w)
        w[i] = w[i-1] + dw
        if V[i] >= V_th:
            spikes[i] = 1
            V[i] = V_reset
            w[i] += b
    return V, w, spikes

# --- Input generators ---
def gen_Icur(amplitude, steps):
    return np.ones(steps) * amplitude

def gen_gaussian(mean, std, steps):
    return np.random.normal(loc=mean, scale=std, size=steps)

def gen_poisson(rate_hz, dt, steps, spike_amplitude=0.5):
    p = rate_hz * dt / 1000.0
    spikes = (np.random.rand(steps) < p).astype(float)
    I = np.zeros(steps)
    pulse_len = max(1, int(1.0/dt))
    for t in np.where(spikes)[0]:
        end = min(steps, t + pulse_len)
        I[t:end] += spike_amplitude
    return I, spikes

# --- Plot helper: input (trace or raster), large membrane trace, output raster ---
def plot_compact_with_raster(I_t, spikes_in, V, spikes_out, dt=0.1, input_color='tab:blue'):
    t = np.arange(len(I_t)) * dt
    fig, axs = plt.subplots(3,1, figsize=(12,7), sharex=True,
                            gridspec_kw={'height_ratios':[1,4,1]})
    # Input: trace or raster
    if spikes_in is None:
        axs[0].plot(t, I_t, color=input_color, linewidth=1.2)
        axs[0].set_ylabel('Input (nA)')
    else:
        axs[0].vlines(t[spikes_in>0], 0, 1, color=input_color, linewidth=1.2)
        axs[0].set_ylabel('Input spikes')
        axs[0].set_ylim(0, 1.2)
    axs[0].set_title('Input (same color for all types)')
    axs[0].grid(alpha=0.12)

    # Large membrane trace (Model cell membrane potential)
    axs[1].plot(t, V, color='tab:green', linewidth=1.4)
    axs[1].set_ylabel('V (mV)')
    axs[1].set_title('Model cell membrane potential (full trace)')
    if spikes_out.sum() > 0:
        ytop = axs[1].get_ylim()[1]
        axs[1].vlines(t[spikes_out>0], ytop-2.0, ytop, color='k', linewidth=0.8)
    axs[1].grid(alpha=0.10)

    # Output spike raster (postsynaptic)
    axs[2].vlines(t[spikes_out>0], 0, 1, color='k', linewidth=1.0)
    axs[2].set_ylim(0,1.2)
    axs[2].set_ylabel('Output spikes')
    axs[2].set_xlabel('Time (ms)')
    axs[2].grid(alpha=0.08)

    plt.tight_layout()
    plt.show()

# --- Interactive wrapper (uses explicit widget objects so we can set description width) ---
def run_aif_raster(Input_Type,
                   Constant_Current_nA,
                   Gaussian_Mean_nA,
                   Gaussian_Std_nA,
                   Poisson_Rate_Hz,
                   Simulation_Duration_ms,
                   Time_Step_dt_ms,
                   Membrane_TimeConstant_tau_m_ms,
                   Adaptation_TimeConstant_tau_w_ms,
                   Adaptation_Increment_b_nA):
    T = Simulation_Duration_ms
    dt = Time_Step_dt_ms
    steps = int(T/dt)
    np.random.seed(1)
    input_color = 'tab:blue'

    if Input_Type == 'Constant current (Icur)':
        I_t = gen_Icur(Constant_Current_nA, steps)
        spikes_in = None
    elif Input_Type == 'Gaussian noise (continuous)':
        I_t = gen_gaussian(Gaussian_Mean_nA, Gaussian_Std_nA, steps)
        spikes_in = None
    elif Input_Type == 'Poisson spike train (events)':
        I_t, spikes_in = gen_poisson(Poisson_Rate_Hz, dt, steps, spike_amplitude=0.5)
    else:
        raise ValueError('Invalid input type')

    V, _, spikes_out = aif_response(I_t, dt=dt, T=T,
                                    V_rest=-65.0, V_th=-50.0, V_reset=-65.0,
                                    R=100.0,
                                    tau_m=Membrane_TimeConstant_tau_m_ms,
                                    tau_w=Adaptation_TimeConstant_tau_w_ms,
                                    b=Adaptation_Increment_b_nA)

    plot_compact_with_raster(I_t, spikes_in if 'spikes_in' in locals() else None, V, spikes_out, dt=dt, input_color=input_color)


# --- Create widgets with extended description width and full descriptive names ---
wide_style = {'description_width': '320px'}
wide_layout = Layout(width='520px')

w_input_type = widgets.Dropdown(
    options=['Constant current (Icur)',
             'Gaussian noise (continuous)',
             'Poisson spike train (events)'],
    value='Constant current (Icur)',
    description='Input Type',
    style=wide_style,
    layout=wide_layout
)

w_constant_current = widgets.FloatSlider(
    min=0.0, max=3.0, step=0.05, value=0.2,
    description='Constant current (Icur) [nA]',
    style=wide_style, layout=wide_layout
)

w_gauss_mean = widgets.FloatSlider(
    min=-1.0, max=1.0, step=0.05, value=0.0,
    description='Gaussian mean (μ) [nA]',
    style=wide_style, layout=wide_layout
)

w_gauss_std = widgets.FloatSlider(
    min=0.0, max=2.0, step=0.05, value=0.5,
    description='Gaussian std (σ) [nA]',
    style=wide_style, layout=wide_layout
)

w_poisson_rate = widgets.IntSlider(
    min=1, max=200, step=1, value=20,
    description='Poisson rate (λ) [Hz]',
    style=wide_style, layout=wide_layout
)

w_duration = widgets.FloatSlider(
    min=200, max=2000, step=100, value=1000,
    description='Simulation duration [ms]',
    style=wide_style, layout=wide_layout
)

w_dt = widgets.FloatSlider(
    min=0.05, max=1.0, step=0.05, value=0.1,
    description='Time step (dt) [ms]',
    style=wide_style, layout=wide_layout
)

w_tau_m = widgets.FloatSlider(
    min=5, max=100, step=1, value=20,
    description='Membrane time constant (τm) [ms]',
    style=wide_style, layout=wide_layout
)

w_tau_w = widgets.FloatSlider(
    min=20, max=1000, step=10, value=200,
    description='Adaptation time constant (τw) [ms]',
    style=wide_style, layout=wide_layout
)

w_b = widgets.FloatSlider(
    min=0.0, max=2.0, step=0.05, value=0.5,
    description='Adaptation increment (b) [nA]',
    style=wide_style, layout=wide_layout
)

# --- Wire up the interactive display ---
ui = widgets.VBox([
    w_input_type,
    w_constant_current,
    w_gauss_mean,
    w_gauss_std,
    w_poisson_rate,
    w_duration,
    w_dt,
    w_tau_m,
    w_tau_w,
    w_b
])

out = widgets.interactive_output(run_aif_raster, {
    'Input_Type': w_input_type,
    'Constant_Current_nA': w_constant_current,
    'Gaussian_Mean_nA': w_gauss_mean,
    'Gaussian_Std_nA': w_gauss_std,
    'Poisson_Rate_Hz': w_poisson_rate,
    'Simulation_Duration_ms': w_duration,
    'Time_Step_dt_ms': w_dt,
    'Membrane_TimeConstant_tau_m_ms': w_tau_m,
    'Adaptation_TimeConstant_tau_w_ms': w_tau_w,
    'Adaptation_Increment_b_nA': w_b
})

display(ui, out)
# Out:
# ...
# Output()

# %% [markdown]
# ### Explain — Input types
#
# *Describe the shape of each input type in your own words (what does the trace look like?):*
#
# **Icur:**
# ```
# [Write here]
# ```
#
# **Gaussian:**
# ```
# [Write here]
# ```
#
# **Poisson:**
# ```
# [Write here]
# ```
#
# *Neurons in the cortex receive input from thousands of other neurons simultaneously. Which input type best captures this, and why?*
#
# **My answer:**
# ```
# [Write here]
# ```
#
# ### Final Checkpoint
#
# - Constant current injection is used in experiments because: ______
# - Gaussian noise models: ______
# - A Poisson spike train represents: ______
#
# ---
#
# ### Bonus — Think deeper
#
# *We often describe a neuron's input-output relationship as a "firing rate curve" — more input = higher firing rate. Does this hold for a bursting neuron or an adapting neuron? If not, what would be a better way to describe the neuron's behaviour?*
#
# **My answer:**
# ```
# [Write here]
# ```
